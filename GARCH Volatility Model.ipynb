# %% [markdown]
# ## Importing libraries

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import datetime as dt
import numpy as np
import seaborn as sns
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
sns.set()
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error, explained_variance_score
from datetime import datetime, timedelta
import pylab
import scipy.stats

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX
from arch import arch_model 
from statsmodels.tsa.arima.model import ARIMA
from scipy.stats.distributions import chi2
from pmdarima.arima import auto_arima
import statsmodels.tsa.stattools as sts
from statsmodels.tsa.seasonal import seasonal_decompose 
import statsmodels.graphics.tsaplots as sgt

# %% [markdown]
# ## Importing the Data

# %%
btcfile = "btc.csv"
ethfile = 'eth.csv'

btc = pd.read_csv(btcfile)
eth = pd.read_csv(ethfile)

# %%
btc.tail()
# Out:
#             date  AdrActCnt  AdrBal1in100KCnt  AdrBal1in100MCnt  \
# 4720  2021-12-06    1078373              9491           2271212
# 4721  2021-12-07     983177              9501           2273648
# 4722  2021-12-08     927369              9504           2272008
# 4723  2021-12-09    1123743              9485           2265030
# 4724  2021-12-10     930831              9489           2266420
#
#       AdrBal1in10BCnt  AdrBal1in10KCnt  AdrBal1in10MCnt  AdrBal1in1BCnt  \
# 4720         16198472             1036           472812         6944550
# 4721         16209029             1037           472957         6955687
# 4722         16228460             1036           472458         6956507
# 4723         16155432             1035           471283         6924788
# 4724         16200870             1033           471759         6934474
#
#       AdrBal1in1KCnt  AdrBal1in1MCnt  AdrBalCnt  AdrBalNtv0.001Cnt  \
# 4720              44          100294   39286031           19171387
# 4721              43          100322   39309060           19173419
# 4722              44          100217   39368474           19197560
# 4723              43          100029   39301999           19122559
# 4724              44          100082   39398449           19184814
#
#       AdrBalNtv0.01Cnt  AdrBalNtv0.1Cnt  AdrBalNtv100Cnt  AdrBalNtv100KCnt  \
# 4720           9351355          3291529            16149                 3
# 4721           9364618          3295526            16169                 3
# 4722           9367838          3293526            16154                 3
# 4723           9324142          3283374            16099                 3
# 4724           9340756          3284971            16100                 3
#
#       AdrBalNtv10Cnt  AdrBalNtv10KCnt  AdrBalNtv1Cnt  AdrBalNtv1KCnt  \
# 4720          148870               86         813636            2153
# 4721          148732               87         813929            2158
# 4722          148687               87         813195            2152
# 4723          148367               87         811029            2150
# 4724          148477               89         811789            2144
#
#       AdrBalNtv1MCnt  AdrBalUSD100Cnt  AdrBalUSD100KCnt  AdrBalUSD10Cnt  \
# 4720               0       16006360.0          459647.0      25972160.0
# 4721               0       16018490.0          460052.0      25983550.0
# 4722               0       16027749.0          458889.0      26026754.0
# 4723               0       15657210.0          406703.0      25630217.0
# 4724               0       15645838.0          403686.0      25669965.0
#
#       AdrBalUSD10KCnt  AdrBalUSD10MCnt  AdrBalUSD1Cnt  AdrBalUSD1KCnt  \
# 4720        2219033.0           9245.0     34561275.0       6816252.0
# 4721        2222245.0           9261.0     34580130.0       6828353.0
# 4722        2218021.0           9238.0     34635010.0       6823240.0
# 4723        2106568.0           8356.0     34421634.0       6577638.0
# 4724        2092773.0           8316.0     34493921.0       6555156.0
#
#       AdrBalUSD1MCnt  AssetEODCompletionTime  BlkCnt  BlkSizeMeanByte  \
# 4720         98239.0              1638848780     172     1.103169e+06
# 4722     1.552801e+07   2.755625e+06     1.870924e+07    1.730736e+07
# 4723     1.542994e+07   2.779729e+06     1.871172e+07    1.731445e+07
# 4724     1.540965e+07   2.783279e+06     1.871271e+07    1.731528e+07
#
#            SplyCur  SplyExpFut10yr        SplyFF  SplyMiner0HopAllNtv  \
# 4720  1.889335e+07    2.063839e+07  1.453782e+07         1.799576e+06
# 4721  1.889431e+07    2.063863e+07  1.453713e+07         1.799564e+06
# 4722  1.889536e+07    2.063889e+07  1.453671e+07         1.799714e+06
# 4723  1.889638e+07    2.063915e+07  1.453720e+07         1.799806e+06
# 4724  1.889736e+07    2.063939e+07  1.453768e+07         1.799973e+06
#
#       SplyMiner0HopAllUSD  SplyMiner1HopAllNtv  SplyMiner1HopAllUSD   TxCnt  \
# 4720         9.094234e+10         2.623279e+06         1.325685e+11  286268
# 4721         9.101199e+10         2.632380e+06         1.331312e+11  284544
# 4722         9.088672e+10         2.640593e+06         1.333517e+11  268196
# 4723         8.627879e+10         2.670606e+06         1.280230e+11  285532
# 4724         8.538575e+10         2.651637e+06         1.257863e+11  270853
#
#       TxCntSec  TxTfrCnt  TxTfrValAdjNtv  TxTfrValAdjUSD  TxTfrValMeanNtv  \
# 4720  3.313287    848083   555379.131291    2.806632e+10         1.774040
# 4721  3.293333    837236   370894.874996    1.875781e+10         1.170250
# 4722  3.104120    794683   309953.083992    1.565283e+10         0.969159
# 4723  3.304769    860423   296193.618654    1.419888e+10         0.766341
# 4724  3.134873    856855   340292.597365    1.614254e+10         0.858970
#
#       TxTfrValMeanUSD  TxTfrValMedNtv  TxTfrValMedUSD  VelCur1yr  \
# 4720     89651.848566        0.002975      150.333288  14.487375
# 4721     59184.778461        0.002683      135.708000  14.513816
# 4722     48943.153102        0.002600      131.304731  14.526414
# 4723     36736.705868        0.002550      122.251995  14.530225
# 4724     40747.160242        0.002437      115.621130  14.536222
#
#       VtyDayRet180d  VtyDayRet30d
# 4720       0.036429      0.037229
# 4721       0.036409      0.036765
# 4722       0.036404      0.033862
# 4723       0.036482      0.034726
# 4724       0.035923      0.034422

# %% [markdown]
# ## Data PreProcessing - Converting our data to time series

# %%
btc.dropna(subset=['PriceUSD'], how='all',inplace= True)      #Dropping Null values from PriceUSD Column
btc.reset_index(inplace=True, drop=True)                       #Index Reset

btc['date'] = pd.to_datetime(btc['date'])          #Converting Date Column to DateTime Object
btc.set_index('date',inplace=True)                  #Setting the date as index for time-series analysis
btc = btc.asfreq('d')                                #Setting frequency to daily

# %%
#Adding Log Price of btc
logP = np.log(btc['PriceUSD'])
btc['logbtc'] = logP
#Adding Returns of btc and eth
#btc['returneth'] = btc.ethusd.pct_change(1).mul(100)
btc['returnbtc'] = btc.PriceUSD.pct_change(1).mul(100)
btc['sqreturnbtc'] = btc.returnbtc.mul(btc.returnbtc)
#add a new column category next to the age group. 
category = pd.cut(btc.CapMVRVFF,bins=[0,1.6,200],labels=['Buy','Sell'])
btc.insert(2,'Action',category)
btc['NetFlowExNtv'] = btc.FlowOutExNtv.subtract(btc.FlowInExNtv )

btc = btc.iloc[1:] #Removing the first row as the return value would be null for it.
btc.head()
# Out:
#             AdrActCnt  AdrBal1in100KCnt Action  AdrBal1in100MCnt  \
# date
# 2010-07-19        929             49297   Sell             52208
# 2010-07-20        936             49367   Sell             52344
# 2010-07-21        784             49382   Sell             52397
# 2010-07-22        594             49504   Sell             52577
# 2010-07-23        655             49604   Sell             52741
#
#             AdrBal1in10BCnt  AdrBal1in10KCnt  AdrBal1in10MCnt  AdrBal1in1BCnt  \
# date
# 2010-07-19            52311              207            51276           52311
# 2010-07-20            52456              213            51353           52456
# 2010-07-21            52521              220            51380           52521
# 2010-07-22            52715              222            51508           52715
# 2010-07-23            52883              226            51632           52883
#
#             AdrBal1in1KCnt  AdrBal1in1MCnt  AdrBalCnt  AdrBalNtv0.001Cnt  \
# date
# 2010-07-19              54           51085      52311              52311
# 2010-07-20              54           51157      52456              52456
# 2010-07-21              54           51179      52521              52521
# 2010-07-22              57           51304      52715              52715
# 2010-07-23              57           51417      52883              52883
#
#             AdrBalNtv0.01Cnt  AdrBalNtv0.1Cnt  AdrBalNtv100Cnt  \
# date
# 2010-07-19             52311            51351              503
# 2010-07-20             52456            51434              515
# 2010-07-21             52521            51460              533
# 2010-07-22             52715            51595              532
# 2010-07-23             52883            51723              546
#
#             AdrBalNtv100KCnt  AdrBalNtv10Cnt  AdrBalNtv10KCnt  AdrBalNtv1Cnt  \
# date
# 2010-07-19                 0           49503               23          51248
# 2010-07-20                 0           49582               23          51325
# 2010-07-21                 0           49600               24          51346
# 2010-07-22                 0           49727               24          51472
# 2010-07-23                 0           49841               23          51592
#
#             AdrBalNtv1KCnt  AdrBalNtv1MCnt  AdrBalUSD100Cnt  AdrBalUSD100KCnt  \
# date
# 2010-07-19             119               0            103.0               0.0
# 2010-07-20             122               0            101.0               0.0
# 2010-07-21             121               0            104.0               0.0
# 2010-07-22             124               0             90.0               0.0
# 2010-07-23             124               0             92.0               0.0
#
#             AdrBalUSD10Cnt  AdrBalUSD10KCnt  AdrBalUSD10MCnt  AdrBalUSD1Cnt  \
# date
# 2010-07-19           400.0              0.0              0.0        49409.0
# 2010-07-20           412.0              0.0              0.0        49480.0
# 2010-07-21           430.0              0.0              0.0        49502.0
# 2010-07-22           356.0              0.0              0.0        49580.0
# 2010-07-23           366.0              0.0              0.0        49687.0
#
#             AdrBalUSD1KCnt  AdrBalUSD1MCnt  AssetEODCompletionTime  BlkCnt  \
# date
# 2010-07-19            19.0             0.0              1614335314     174
# 2010-07-20            17.0             0.0              1614335315     181
# 2010-07-21            18.0             0.0              1614335316     207
# 2010-07-22            14.0             0.0              1614335317     176
# 2010-07-23            16.0             0.0              1614335318     194
#
#             BlkSizeMeanByte  BlkWghtMean  BlkWghtTot  CapAct1yrUSD  \
# date
# 2010-07-19       800.310345  3201.241379      557016  83085.000568
# 2010-07-19        3456500.0        787563.72       3456147.86
# 2010-07-20        3465550.0        787513.72       3465189.86
# 2010-07-21        3475900.0        790313.72       3475536.67
# 2010-07-22        3484700.0        798363.76       3484330.01
# 2010-07-23        3494400.0        796438.76       3494011.03
#
#             SplyAdrBalNtv0.001  SplyAdrBalNtv0.01  SplyAdrBalNtv0.1  \
# date
# 2010-07-19           3456500.0          3456500.0        3456456.09
# 2010-07-20           3465550.0          3465550.0        3465503.36
# 2010-07-21           3475900.0          3475900.0        3475851.85
# 2010-07-22           3484700.0          3484700.0        3484649.49
# 2010-07-23           3494400.0          3494400.0        3494347.63
#
#             SplyAdrBalNtv1  SplyAdrBalNtv10  SplyAdrBalNtv100  \
# date
# 2010-07-19      3456427.72       3448219.01        1004792.01
# 2010-07-20      3465473.54       3457301.60        1010874.95
# 2010-07-21      3475819.14       3467630.17        1021345.45
# 2010-07-22      3484614.76       3476431.58        1023945.58
# 2010-07-23      3494309.95       3486117.43        1028987.61
#
#             SplyAdrBalNtv100K  SplyAdrBalNtv10K  SplyAdrBalNtv1K  \
# date
# 2010-07-19                0.0         600278.71        908421.45
# 2010-07-20                0.0         600528.71        910722.43
# 2010-07-21                0.0         611312.71        914211.60
# 2010-07-22                0.0         611312.71        918699.24
# 2010-07-23                0.0         600759.31        918229.84
#
#             SplyAdrBalNtv1M  SplyAdrBalUSD1  SplyAdrBalUSD10  \
# date
# 2010-07-19                0      3447271.73        994389.08
# 2010-07-20                0      3456259.58       1000396.17
# 2010-07-21                0      3466643.52       1010881.52
# 2010-07-22                0      3474728.35       1002509.25
# 2010-07-23                0      3484347.94       1006994.91
#
#             SplyAdrBalUSD100  SplyAdrBalUSD100K  SplyAdrBalUSD10K  \
# date
# 2010-07-19         891732.43                0.0               0.0
# 2010-07-20         888532.43                0.0               0.0
# 2010-07-21         896376.62                0.0               0.0
# 2010-07-22         877231.64                0.0               0.0
# 2010-07-23         879871.64                0.0               0.0
#
#             SplyAdrBalUSD10M  SplyAdrBalUSD1K  SplyAdrBalUSD1M  SplyAdrTop100  \
# date
# 2010-07-19               0.0        559006.78              0.0      887733.04
# 2010-07-20               0.0        533953.38              0.0      887183.04
# 2010-07-21               0.0        546603.38              0.0      891077.23
# 2010-07-22               0.0        485185.59              0.0      892154.26
# 2010-07-23               0.0        518853.38              0.0      891721.26
#
#             SplyAdrTop10Pct  SplyAdrTop1Pct    SplyCur  SplyExpFut10yr  \
# date
# 2010-07-19       1242146.56      1006476.63  3456500.0      17934137.5
# 2010-07-20       1248322.86      1011713.58  3465550.0      17936400.0
# 2010-07-21       1258230.22      1020545.45  3475900.0      17938987.5
# 2010-07-22       1261845.08      1023445.58  3484700.0      17941187.5
# 2010-07-23       1267121.63      1027187.61  3494400.0      17943612.5
#
#                SplyFF  SplyMiner0HopAllNtv  SplyMiner0HopAllUSD  \
# date
# 2010-07-19  3456500.0           2380385.34        192335.135472
# 2010-07-20  3465550.0           2382935.23        178090.401130
# 2010-07-21  3475900.0           2382535.18        188679.781277
# 2010-07-22  3484700.0           2387935.16        139621.996594
# 2010-07-23  3494400.0           2391735.17        144922.097433
#
#             SplyMiner1HopAllNtv  SplyMiner1HopAllUSD  TxCnt  TxCntSec  \
# date
# 2010-07-19           3124984.49        252498.746792    334  0.003866
# 2010-07-20           3132645.14        234120.517652    423  0.004896
# 2010-07-21           3139232.45        248604.804250    247  0.002859
# 2010-07-22           3143642.45        183808.020753    221  0.002558
# 2010-07-23           3149700.74        190849.406428    220  0.002546
#
#             TxTfrCnt  TxTfrValAdjNtv  TxTfrValAdjUSD  TxTfrValMeanNtv  \
# date
# 2010-07-19       512        40243.73     3251.693384        86.951152
# 2010-07-20       738        16063.23     1200.497201        42.528835
# 2010-07-21       377        20834.15     1649.915979        71.822334
# 2010-07-22       344        33049.03     1932.368865       112.714622
# 2010-07-23       335        19258.75     1166.942929        63.158149
#
#             TxTfrValMeanUSD  TxTfrValMedNtv  TxTfrValMedUSD  VelCur1yr  \
# date
# 2010-07-19         7.025653           2.625        0.212100   1.828863
# 2010-07-20         3.178423           1.375        0.102762   1.831412
# 2010-07-21         5.687816          18.500        1.465068   1.833749
# 2010-07-22         6.590397           1.010        0.059054   1.840245
# 2010-07-23         3.826934           5.000        0.302964   1.841192
#
#             VtyDayRet180d  VtyDayRet30d    logbtc  returnbtc  sqreturnbtc  \
# date
# 2010-07-19            NaN           NaN -2.515778  -5.871389    34.473204
# 2010-07-20            NaN           NaN -2.593797  -7.505286    56.329320
# 2010-07-21            NaN           NaN -2.535869   5.963859    35.567620
# 2010-07-22            NaN           NaN -2.839246 -26.167891   684.758539
# 2010-07-23            NaN           NaN -2.803578   3.631124    13.185059
#
#             NetFlowExNtv
# date
# 2010-07-19           0.0
# 2010-07-20           0.0
# 2010-07-21           0.0
# 2010-07-22           0.0
# 2010-07-23           0.0

# %%
btc.to_csv('btcpro.csv')

# %%
eth.dropna(subset=['PriceUSD'], how='all',inplace= True)          #Dropping Null values from PriceUSD Column
eth.reset_index(inplace=True, drop=True)                           #Index Reset

eth['date'] = pd.to_datetime(eth['date'])                     #Converting Date Column to DateTime Object
eth.set_index('date',inplace=True)                             #Setting the date as index for time-series analysis
eth = eth.asfreq('d')                                           #Setting frequency to daily

# %%
#Adding Log Price of eth
logP = np.log(eth['PriceUSD'])
eth['logeth'] = logP
#Adding Returns of btc and eth
#btc['returneth'] = btc.ethusd.pct_change(1).mul(100)
eth['returneth'] = eth.PriceUSD.pct_change(1).mul(100)
eth['sqreturneth'] = eth.returneth.mul(eth.returneth)
#add a new column category next to the age group. 
category = pd.cut(eth.CapMVRVFF,bins=[0,1.6,200],labels=['Buy','Sell'])
eth.insert(2,'Action',category)
eth['NetFlowExNtv'] = eth.FlowOutExNtv.subtract(eth.FlowInExNtv )

eth = eth.iloc[1:] #Removing the first row as the return value would be null for it.
eth.head()
# Out:
#             AdrActCnt  AdrBal1in100KCnt Action  AdrBal1in100MCnt  \
# date
# 2015-08-09       1113              5458   Sell             10043
# 2015-08-10       1430              5443   Sell             10145
# 2015-08-11       2697              5425   Sell             10188
# 2015-08-12       1219              5413   Sell             10296
# 2015-08-13       1606              5389   Sell             10449
#
#             AdrBal1in10BCnt  AdrBal1in10KCnt  AdrBal1in10MCnt  AdrBal1in1BCnt  \
# date
# 2015-08-09            10411             1169             9573           10222
# 2015-08-10            10572             1160             9611           10348
# 2015-08-11            10706             1160             9614           10429
# 2015-08-12            10893             1157             9654           10574
# 2015-08-13            11145             1153             9717           10757
#
#             AdrBal1in1KCnt  AdrBal1in1MCnt  AdrBalCnt  AdrBalNtv0.001Cnt  \
# date
# 2015-08-09             142            8091      10846              10476
# 2015-08-10             138            8101      11101              10660
# 2015-08-11             137            8081      11374              10821
# 2015-08-12             135            8105      11677              11009
# 2015-08-13             133            8125      12152              11272
#
#             AdrBalNtv0.01Cnt  AdrBalNtv0.1Cnt  AdrBalNtv100Cnt  \
# date
# 2015-08-09             10338            10150             7882
# 2015-08-10             10486            10265             7887
# 2015-08-11             10602            10328             7868
# 2015-08-12             10771            10463             7889
# 2015-08-13             11003            10638             7910
#
#             AdrBalNtv100KCnt  AdrBalNtv10Cnt  AdrBalNtv10KCnt  AdrBalNtv1Cnt  \
# date
# 2015-08-09               115            9523              966           9914
# 2015-08-10               113            9555              954          10000
# 2015-08-11               111            9548              947          10030
# 2015-08-12               112            9585              944          10114
# 2015-08-13               111            9628              938          10249
#
#             AdrBalNtv1KCnt  AdrBalNtv1MCnt  AdrBalUSD100Cnt  AdrBalUSD100KCnt  \
# date
# 2015-08-09            5124               3           8011.0             127.0
# 2015-08-10            5094               3           8020.0             124.0
# 2015-08-11            5079               4           7656.0              80.0
# 2015-08-12            5065               4           8074.0             132.0
# 2015-08-13            5044               4           8322.0             165.0
#
#             AdrBalUSD10Cnt  AdrBalUSD10KCnt  AdrBalUSD10MCnt  AdrBalUSD1Cnt  \
# date
# 2015-08-09          9555.0           1059.0              1.0        10031.0
# 2015-08-10          9593.0           1047.0              1.0        10133.0
# 2015-08-11          9475.0            753.0              1.0         9995.0
# 2015-08-12          9645.0           1130.0              1.0        10291.0
# 2015-08-13          9770.0           1437.0              1.0        10474.0
#
#             AdrBalUSD1KCnt  AdrBalUSD1MCnt  AssetEODCompletionTime  BlkCnt  \
# date
# 2015-08-09          5346.0             5.0              1614334931    5123
# 2015-08-10          5321.0             5.0              1614334931    5255
# 2015-08-11          4597.0             3.0              1614334932    5280
# 2015-08-12          5364.0             6.0              1614334932    5124
# 2015-08-13          5644.0            10.0              1614334932    5286
#
#             BlkSizeMeanByte  CapAct1yrUSD  CapMVRVCur  CapMVRVFF  \
# date
# 2015-08-09       618.298068  1.828813e+07    4.880815   4.023108
# 2015-08-10       631.186108  1.930666e+07    4.623448   3.811280
# 2015-08-11       692.014015  1.632495e+07    3.834275   3.160996
# 2015-08-12       653.426425  2.161357e+07    4.702081   3.876732
# 2015-08-12   906.070809 -221425.355691
# 2015-08-13  2146.969639 -419072.164903

# %%
eth.to_csv('ethpro.csv')

# %% [markdown]
# ### Twitter Sentiment Data

# %%
btc_s = pd.read_csv('btc_sentiment.csv')
eth_s = pd.read_csv('eth_sentiment.csv')

# %%
btc_s = btc_s.rename(columns={"polarity": "btcpolarity", "subjectivity": "btcsubjectivity"})
eth_s = eth_s.rename(columns={"polarity": "ethpolarity", "subjectivity": "ethsubjectivity"})

btc_s.reset_index(inplace=True, drop=True)                           #Index Reset
btc_s['date'] = pd.to_datetime(btc_s['date'])                     #Converting Date Column to DateTime Object
btc_s.set_index('date',inplace=True)                             #Setting the date as index for time-series analysis
btc_s = btc_s.asfreq('d')

eth_s.reset_index(inplace=True, drop=True)                           #Index Reset
eth_s['date'] = pd.to_datetime(eth_s['date'])                     #Converting Date Column to DateTime Object
eth_s.set_index('date',inplace=True)                             #Setting the date as index for time-series analysis
eth_s = eth_s.asfreq('d')

# %%
df1 = eth[['PriceUSD']].copy()                                 # Merging btc and eth price into one dataframe
df1.columns = ['ethusd']     
df = pd.concat([df1,btc[['PriceUSD']]], axis = 1)        
df.columns = ['ethusd', 'btcusd']
df.dropna(inplace= True)
df.head()
# Out:
#              ethusd      btcusd
# date
# 2015-08-09  1.19999  266.342020
# 2015-08-10  1.19999  264.928825
# 2015-08-11  0.99000  271.421736
# 2015-08-12  1.28800  268.143868
# 2015-08-13  1.88480  264.691628

# %%
btc.NetFlowExNtv.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
df.shape
# Out:
# (2316, 2)

# %% [markdown]
# ### Creating new Data- Returns and log Price

# %%
#Adding Log Price of btc and eth
logP1 = np.log(df['ethusd'])
df['logeth'] = logP1
logP = np.log(df['btcusd'])
df['logbtc'] = logP

#Adding Returns of btc and eth
df['returneth'] = df.ethusd.pct_change(1).mul(100)
df['returnbtc'] = df.btcusd.pct_change(1).mul(100)
df['sqreturnbtc'] = df.returnbtc.mul(df.returnbtc)
df['logret'] = np.log( df['btcusd'] / df['btcusd'].shift(1) ).mul(100)
df = df.iloc[1:] #Removing the first row as the return value would be null for it.
df.head()
# Out:
#               ethusd      btcusd    logeth    logbtc  returneth  returnbtc  \
# date
# 2015-08-10  1.199990  264.928825  0.182313  5.579461   0.000000  -0.530594
# 2015-08-11  0.990000  271.421736 -0.010050  5.603674 -17.499312   2.450813
# 2015-08-12  1.288000  268.143868  0.253091  5.591524  30.101010  -1.207666
# 2015-08-13  1.884800  264.691628  0.633822  5.578565  46.335404  -1.287458
# 2015-08-14  1.795044  266.355942  0.585030  5.584834  -4.762088   0.628775
#
#             sqreturnbtc    logret
# date
# 2015-08-10     0.281530 -0.532007
# 2015-08-11     6.006486  2.421263
# 2015-08-12     1.458457 -1.215017
# 2015-08-13     1.657549 -1.295818
# 2015-08-14     0.395357  0.626806

# %%
df.tail()
# Out:
#                  ethusd        btcusd    logeth     logbtc  returneth  \
# date
# 2021-12-06  4341.941021  50535.425223  8.376077  10.830430   3.611918
# 2021-12-07  4303.762652  50574.472834  8.367245  10.831202  -0.879293
# 2021-12-08  4427.312634  50500.654351  8.395548  10.829742   2.870743
# 2021-12-09  4157.287480  47937.822846  8.332618  10.777660  -6.099076
# 2021-12-10  3931.613105  47437.228973  8.276805  10.767163  -5.428404
#
#             returnbtc  sqreturnbtc    logret
# date
# 2021-12-06   2.449631     6.000691  2.420108
# 2021-12-07   0.077268     0.005970  0.077238
# 2021-12-08  -0.145960     0.021304 -0.146067
# 2021-12-09  -5.074848    25.754083 -5.208148
# 2021-12-10  -1.044257     1.090472 -1.049747

# %% [markdown]
# ## EDA

# %%
import matplotlib.pyplot as plt

df.plot( y = ["btcusd","ethusd"], logy = True, figsize=(22,9) )
plt.title("Bitcoin vs Eth over time", size=25)
plt.xlabel("Time (Years)", size=20)
plt.ylabel("BTC Price in Log", size=20)
plt.show()

# %%
import matplotlib.pyplot as plt

df.plot(y='returnbtc', figsize=(22,9) )
plt.title("Daily Returns of Bitcoin over time", size=25)
plt.xlabel("Time (Years)", size=20)
plt.ylabel("Return (%)", size=20)
# Out:
# Text(0, 0.5, 'Return (%)')

# %%
sgt.plot_acf(df.btcusd, lags = 40 , zero = False)
plt.title("ACF BTC Price" )
plt.show()

# %%
sgt.plot_pacf(df.btcusd, lags = 40 , zero = False, method = ('ols'))
plt.title("PACF BTC Price" )
plt.show()

# %%
sgt.plot_acf(df.returnbtc, lags = 40 , zero = False)
plt.title("ACF BTC Return" )
plt.show()

# %%
sgt.plot_pacf(df.returnbtc, lags = 40 , zero = False, method = ('ols'))
plt.title("PACF BTC Return" )
plt.show()

# %%
#Seasonality
sdecadd = seasonal_decompose(df.btcusd , model='multiplicative')
sdecadd.plot()
plt.show()

# %%
scipy.stats.probplot(df.logret,plot = pylab)  #QQ Plot
pylab.show()

# %%
sts.adfuller(df.logret) #Determing Covariance Stationarity (Dicker-Fuller test)
# Out:
# (-50.03924480930481,
#  0.0,
#  0,
#  2314,
#  {'1%': -3.4331791136300738,
#   '5%': -2.862789843219427,
#   '10%': -2.5674353474136984},
#  12824.629855204083)

# %% [markdown]
# ### Corelation between varios parameters with price

# %%
print("Correlation of Price of BTC and ETH = ",df.btcusd.corr(df.ethusd))
# Out:
# Correlation of Price of BTC and ETH =  0.929674599866767

# %%
print("Corr of BTC Price and Active Address count = " ,btc.PriceUSD.corr(btc.AdrActCnt))
# Out:
# Corr of BTC Price and Active Address count =  0.6537043109858226

# %%
print("Corr of Mean Difficulty and Hash Rate = ",btc.DiffMean.corr(btc.HashRate))
# Out:
# Corr of Mean Difficulty and Hash Rate =  0.989717931113273

# %% [markdown]
# ### Splitting the dataset

# %%
size = int(len(df)*0.8)
size
# Out:
# 1852

# %%
train = df.iloc[:size]
test = df.iloc[size:]
train.tail()
# Out:
#                 ethusd        btcusd    logeth    logbtc  returneth  \
# date
# 2020-08-30  428.196438  11698.975833  6.059582  9.367257   6.950671
# 2020-08-31  436.090769  11678.348227  6.077850  9.365492   1.843624
# 2020-09-01  480.749176  11970.364856  6.175346  9.390189  10.240622
# 2020-09-02  441.214134  11414.520934  6.089530  9.342642  -8.223632
# 2020-09-03  383.542585  10261.494410  5.949451  9.236154 -13.071102
#
#             returnbtc  sqreturnbtc     logret
# date
# 2020-08-30   1.812008     3.283371   1.795786
# 2020-08-31  -0.176320     0.031089  -0.176475
# 2020-09-01   2.500496     6.252480   2.469745
# 2020-09-02  -4.643500    21.562095  -4.754769
# 2020-09-03 -10.101401   102.038301 -10.648783

# %%
from matplotlib import pyplot

print('Observations: %d' % (len(df)))
print('Training Observations: %d' % (len(train)))
print('Testing Observations: %d' % (len(test)))
pyplot.plot(train.logbtc)
pyplot.plot(test.logbtc)
pyplot.title('BTC Price($) in Log scale')
pyplot.show()
# Out:
# Observations: 2315
# Training Observations: 1852
# Testing Observations: 463

# %% [markdown]
# ### Time series Model- GARCH Model to Forecast Volatility

# %%
df.sqreturnbtc.plot() #Volatility
# Out:
# <AxesSubplot:xlabel='date'>

# %%
rolling_predictions = []
test_size = 365

for i in range(test_size):
    train = df.logret[:-(test_size-i)]
    model = arch_model(train,mean = 'Constant' , vol = 'GARCH' , p = 1,q= 1, dist = 'Normal')
    model_fit = model.fit(disp='off')
    pred = model_fit.forecast(horizon=1,reindex=True)
    rolling_predictions.append(np.sqrt(pred.variance.values[-1,:][0]))

# %%
rolling_predictions = pd.Series(rolling_predictions, index=df.index[-365:])

# %%
plt.figure(figsize=(20,8))
true, = plt.plot(df.sqreturnbtc[-365:].mul(1/3))
preds, = plt.plot(rolling_predictions.mul(rolling_predictions))
plt.title('Volatility Prediction for the year 2021 - Rolling Forecast', fontsize=20)
plt.xlabel("Time", size=20)
plt.ylabel("Volatality", size=20)
plt.legend(['True Volatility', 'Predicted Volatility'], fontsize=16)

# %%
print(f'R2: {r2_score(df.sqreturnbtc[-365:].mul(1/3), rolling_predictions.mul(rolling_predictions)):.2f}')
print(f'MAE: {mean_absolute_error(df.sqreturnbtc[-365:].mul(1/3), rolling_predictions.mul(rolling_predictions)):.2f}')
print(f'MSE: {mean_squared_error(df.sqreturnbtc[-365:].mul(1/3), rolling_predictions.mul(rolling_predictions)):.2f}')
print(f'EVS: {explained_variance_score(df.sqreturnbtc[-365:].mul(1/3), rolling_predictions.mul(rolling_predictions)):.2f}')
# Out:
# R2: -2.10
# MAE: 15.43
# MSE: 338.42
# EVS: -0.59

# %%
from sklearn import preprocessing
normtrue = preprocessing.normalize([df.sqreturnbtc[-365:]])
normpred = preprocessing.normalize([rolling_predictions.mul(rolling_predictions)])

# %%
print(f'R2: {r2_score(normtrue[0],normpred[0]):.4f}')
print(f'MAE: {mean_absolute_error(normtrue,normpred):.2f}')
print(f'MSE: {mean_squared_error(normtrue,normpred):.4f}')
print(f'EVS: {explained_variance_score(normtrue,normpred):.2f}')
# Out:
# R2: -0.3992
# MAE: 0.04
# MSE: 0.0029
# EVS: 1.00
