# %%
#importing libraries
import pandas as pd
import numpy as np
import pandas_datareader as web
import seaborn as sns
import matplotlib.pyplot as plt
import mplfinance as mpf
import datetime as dt
from matplotlib.pyplot import figure

# %%
#selecting currency
currency = "USD"
metric = "Close"

# %%
#selecting starting date and end date
start = dt.datetime(2016, 10, 10)
end = dt.datetime.now()

# %%
#allocating empty variables for individual ticker symbol
#working on BITCOIN first
cryptocurr = ['BTC']
colnames = []

# %%
#fetching data of bitcoin-BTC
first = True
for ticker01 in cryptocurr:
  data = web.DataReader(f'{ticker01}-{currency}', "yahoo", start, end)
  if first:
    data02 = data[[metric]].copy()
    colnames.append(ticker01)
    data02.columns = colnames
    first = False
  else:
    data02 = data02.join(data[metric])
    colnames.append(ticker01)
    data02.columns = colnames

#plotting line graph 
plt.yscale('log')

for ticker01 in cryptocurr:
  plt.plot(data02[ticker01], label = ticker01)

plt.legend(loc="upper right")
plt.show()

# %%
#allocating empty variables for individual ticker symbol
#working on ETHEREUM
cryptocurr = ['ETH']
colnames = []

# %%
#fetching data of bitcoin-BTC
first = True
for ticker01 in cryptocurr:
  data = web.DataReader(f'{ticker01}-{currency}', "yahoo", start, end)
  if first:
    data02 = data[[metric]].copy()
    colnames.append(ticker01)
    data02.columns = colnames
    first = False
  else:
    data02 = data02.join(data[metric])
    colnames.append(ticker01)
    data02.columns = colnames

#plotting line graph 
plt.yscale('log')

for ticker01 in cryptocurr:
  plt.plot(data02[ticker01], label = ticker01)

plt.legend(loc="upper right")
plt.show()

# %%
#allocating empty variables for individual ticker symbol
#working on LITECOIN
cryptocurr = ['LTC']
colnames = []

# %%
#fetching data of bitcoin-BTC
first = True
for ticker01 in cryptocurr:
  data = web.DataReader(f'{ticker01}-{currency}', "yahoo", start, end)
  if first:
    data02 = data[[metric]].copy()
    colnames.append(ticker01)
    data02.columns = colnames
    first = False
  else:
    data02 = data02.join(data[metric])
    colnames.append(ticker01)
    data02.columns = colnames

#plotting line graph 
plt.yscale('log')

for ticker01 in cryptocurr:
  plt.plot(data02[ticker01], label = ticker01)

plt.legend(loc="upper right")
plt.show()

# %%
#allocating empty variables for individual ticker symbol
#working on POLYGON
cryptocurr = ['MATIC']
colnames = []

# %%
#fetching data of polygon-MATIC
first = True
for ticker01 in cryptocurr:
  data = web.DataReader(f'{ticker01}-{currency}', "yahoo", start, end)
  if first:
    data02 = data[[metric]].copy()
    colnames.append(ticker01)
    data02.columns = colnames
    first = False
  else:
    data02 = data02.join(data[metric])
    colnames.append(ticker01)
    data02.columns = colnames

#plotting line graph 
plt.yscale('log')

for ticker01 in cryptocurr:
  plt.plot(data02[ticker01], label = ticker01)

plt.legend(loc="upper right")
plt.show()

# %%
#allocating empty variables for individual ticker symbol
#working on DOGECOIN
cryptocurr = ['DOGE']
colnames = []

# %%
#fetching data of dogecoin-DOGE
first = True
for ticker01 in cryptocurr:
  data = web.DataReader(f'{ticker01}-{currency}', "yahoo", start, end)
  if first:
    data02 = data[[metric]].copy()
    colnames.append(ticker01)
    data02.columns = colnames
    first = False
  else:
    data02 = data02.join(data[metric])
    colnames.append(ticker01)
    data02.columns = colnames

#plotting line graph 
plt.yscale('log')

for ticker01 in cryptocurr:
  plt.plot(data02[ticker01], label = ticker01)

plt.legend(loc="upper right")
plt.show()

# %%
#allocating empty variables for individual ticker symbol
#working on RIPPLE
cryptocurr = ['XRP']
colnames = []

# %%
#fetching data of ripple-XRP
first = True
for ticker01 in cryptocurr:
  data = web.DataReader(f'{ticker01}-{currency}', "yahoo", start, end)
  if first:
    data02 = data[[metric]].copy()
    colnames.append(ticker01)
    data02.columns = colnames
    first = False
  else:
    data02 = data02.join(data[metric])
    colnames.append(ticker01)
    data02.columns = colnames

#plotting line graph 
plt.yscale('log')

for ticker01 in cryptocurr:
  plt.plot(data02[ticker01], label = ticker01)

plt.legend(loc="upper right")
plt.show()

# %%
#allocating empty variables for individual ticker symbol
#working on DECENTRALAND
cryptocurr = ['MANA']
colnames = []

# %%
#fetching data of decentraland-MANA
first = True
for ticker01 in cryptocurr:
  data = web.DataReader(f'{ticker01}-{currency}', "yahoo", start, end)
  if first:
    data02 = data[[metric]].copy()
    colnames.append(ticker01)
    data02.columns = colnames
    first = False
  else:
    data02 = data02.join(data[metric])
    colnames.append(ticker01)
    data02.columns = colnames

#plotting line graph 
plt.yscale('log')

for ticker01 in cryptocurr:
  plt.plot(data02[ticker01], label = ticker01)

plt.legend(loc="upper right")
plt.show()

# %%
#allocating empty variables for individual ticker symbol
#working on POLYGON and DECENTRALAND
cryptocurr = ['MANA', 'MATIC']
colnames = []

# %%
#fetching data of POLYGON and DECENTRALAND
first = True
for ticker01 in cryptocurr:
  data = web.DataReader(f'{ticker01}-{currency}', "yahoo", start, end)
  if first:
    data02 = data[[metric]].copy()
    colnames.append(ticker01)
    data02.columns = colnames
    first = False
  else:
    data02 = data02.join(data[metric])
    colnames.append(ticker01)
    data02.columns = colnames

#plotting line graph 
plt.yscale('log')

for ticker01 in cryptocurr:
  plt.plot(data02[ticker01], label = ticker01)

plt.legend(loc="upper right")
plt.show()

#plotting heatmap
data02 = data02.pct_change().corr(method = "pearson")
sns.heatmap(data02, annot = True, cmap = "coolwarm")
plt.figure(figsize=(50, 50))
plt.show()

# %%
#allocating empty variables for individual ticker symbol
#working on BITCOIN and ETHEREUM
cryptocurr = ['BTC', 'ETH']
colnames = []

# %%
#fetching data of BITCOIN and ETHEREUM
first = True
for ticker01 in cryptocurr:
  data = web.DataReader(f'{ticker01}-{currency}', "yahoo", start, end)
  if first:
    data02 = data[[metric]].copy()
    colnames.append(ticker01)
    data02.columns = colnames
    first = False
  else:
    data02 = data02.join(data[metric])
    colnames.append(ticker01)
    data02.columns = colnames

#plotting line graph 
plt.yscale('log')

for ticker01 in cryptocurr:
  plt.plot(data02[ticker01], label = ticker01)

plt.legend(loc="upper right")
plt.show()

#plotting heatmap
data02 = data02.pct_change().corr(method = "pearson")
sns.heatmap(data02, annot = True, cmap = "coolwarm")
plt.figure(figsize=(50, 50))
plt.show()

# %%
#allocating empty variables for individual ticker symbol
#working on ETHEREUM AND POLYGON
cryptocurr = ['ETH', 'MATIC']
colnames = []

# %%
#fetching data of ETHEREUM AND POLYGON
first = True
for ticker01 in cryptocurr:
  data = web.DataReader(f'{ticker01}-{currency}', "yahoo", start, end)
  if first:
    data02 = data[[metric]].copy()
    colnames.append(ticker01)
    data02.columns = colnames
    first = False
  else:
    data02 = data02.join(data[metric])
    colnames.append(ticker01)
    data02.columns = colnames

#plotting line graph 
plt.yscale('log')

for ticker01 in cryptocurr:
  plt.plot(data02[ticker01], label = ticker01)

plt.legend(loc="upper right")
plt.show()

#plotting heatmap
data02 = data02.pct_change().corr(method = "pearson")
sns.heatmap(data02, annot = True, cmap = "coolwarm")
plt.figure(figsize=(50, 50))
plt.show()

# %%
#allocating empty variables for individual ticker symbol
#comparing BITCOIN, ETHEREUM, LITECOIN, POLYGON, DOGECOIN, RIPPLE, DECENTRALAND
cryptocurr = ['BTC', 'ETH', 'LTC', 'MATIC', 'DOGE', 'XRP', 'MANA']
colnames = []

# %%
#fetching data of BITCOIN, ETHEREUM, LITECOIN, POLYGON, DOGECOIN, RIPPLE, DECENTRALAND
first = True
for ticker01 in cryptocurr:
  data = web.DataReader(f'{ticker01}-{currency}', "yahoo", start, end)
  if first:
    data02 = data[[metric]].copy()
    colnames.append(ticker01)
    data02.columns = colnames
    first = False
  else:
    data02 = data02.join(data[metric])
    colnames.append(ticker01)
    data02.columns = colnames

#plotting line graph 
plt.yscale('log')

for ticker01 in cryptocurr:
  plt.plot(data02[ticker01], label = ticker01)

plt.legend(loc="upper right")
plt.show()

#plotting heatmap
data02 = data02.pct_change().corr(method = "pearson")
sns.heatmap(data02, annot = True, cmap = "coolwarm")
plt.figure(figsize=(50, 50))
plt.show()

# %%
#Training AND testing
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.layers import Dense, Dropout, LSTM
from tensorflow.keras.models import Sequential
# Out:
# INFO:tensorflow:Enabling eager execution
# INFO:tensorflow:Enabling v2 tensorshape
# INFO:tensorflow:Enabling resource variables
# INFO:tensorflow:Enabling tensor equality
# INFO:tensorflow:Enabling control flow v2

# %%
crypto_curr = 'BTC', 'ETH', 'LTC', 'MATIC', 'DOGE', 'XRP', 'MANA'
against_curr = ['USD']

# %%
start = dt.datetime(2016,1,1)
end = dt.datetime.now()

datadb = web.DataReader(f'{crypto_curr}-{against_curr}', 'yahoo', start, end)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\dhruv\appdata\local\programs\python\python39\lib\site-packages\pandas_datareader\yahoo\daily.py in _read_one_data(self, url, params)
#     152             j = json.loads(re.search(ptrn, resp.text, re.DOTALL).group(1))
# --> 153             data = j["context"]["dispatcher"]["stores"]["HistoricalPriceStore"]
#     154         except KeyError:
#
# KeyError: 'HistoricalPriceStore'
#
# During handling of the above exception, another exception occurred:
#
# RemoteDataError                           Traceback (most recent call last)
# <ipython-input-33-f0a84dcdf215> in <module>
#       2 end = dt.datetime.now()
#       3
# ----> 4 datadb = web.DataReader(f'{crypto_curr}-{against_curr}', 'yahoo', start, end)
#
# ...
